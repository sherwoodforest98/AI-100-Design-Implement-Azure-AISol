# %% [markdown]
# <a href="https://colab.research.google.com/github/sherwoodforest98/AI-100-Design-Implement-Azure-AISol/blob/master/Peter_Smith_QA_Final_Project_Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical Machine Learning
# ### Project: Model Selection

# %% [markdown]
# # Abstract

# %% [markdown]
# # Part 1: Business and Data Understanding

# %% [markdown]
# ### Q. Identify a suitable dataset for your canditate question(s)

# %% [markdown]
# Go have a look at any of these websites:
#
# * https://www.kaggle.com/datasets
# * https://datasetsearch.research.google.com/
# * https://data.gov.uk/
#
# Find an interesting looking data set related to your problem domain and get a copy of it

# %% [markdown]
# ![Screenshot (2).png](data:image/png;base64,...)

# %% [markdown]
# ### Q. Define the problem domain

# %%
# Using the MPG column as the label to show the characteristics involved to calculate the miles per gallon of a car. Useful statistic when weighing up options regarding efficiancy when choosing a car for purchase.

# %% [markdown]
# ### Q. Identify candidate questions for your machine learning project

# %%
# What is the label?
# I evaluated all the columns and identified the MPG column as the "label"

# Are all Columns required? I evaluated all the columns deciphered that the car column was not needed.
# I evaluated all the columns deciphered that the car column was not needed. However, I decided to include the car column to add a variety of text and numbers to the project.

# Does the dataset need cleaning?
# I evaluated all columns and rows. There were no obvous outliers and no null values.
# When using the "Select Columns in Dataset" asset i noticed their were empty columns being identified. Therefore, using the asset settings, i excluded the blank coulmns from being used in th epipeline process. The attached screenshot shows how i did this

# %% [markdown]
# ![Screenshot (3).png](data:image/png;base64,...)

# %% [markdown]
# ### Q. Generate a descriptive statistics report for the columns in your dataset

# %% [markdown]
# ![Screenshot (8).png](data:image/png;base64,...)

# %% [markdown]
# # Part 2: Data Preparation

# %% [markdown]
# ### Q. Discuss the following types of missing data and how they would be handled in reference to your dataset where applicable.
# *	Missing completely at random (MCAR)
# *	Missing at random (MAR)
# *	Missing Not at Random (MNAR)

# %% [markdown]
# Q. Is there any correlation in the data? How would you decide which columns to keep?

# %%
# Kept all columns with any data. Just excluded blank columns that azure had identified to use.

# %% [markdown]
# Q. Is there any imbalance in the label
# ?

# %%
# The range of the label column was 9 - 35 and felt all data was relevant to for consideration.

# %% [markdown]
# Q. Are there any outliers in the dataset? What do you do with them?

# %%
# No. There were no outliers

# %% [markdown]
# Q. Are there any strings in the features that need to be converted to integers? Do you select One-Hot encoding or Label Encoding?

# %%
# The cars column was not needed for calculation purposes. But i kept the column to add a layer of diversity to the project.
# In my Azure pipeline i used the feature hashing asset to convert the car text string to a numerical value.

# %% [markdown]
# Q. Split the data for TRAINING and SCORING (testing). OPTIONAL: Discuss what problems could happen we have poor distribution b/w training and testing?

# %% [markdown]
# # Part 3: Model Selection

# %% [markdown]
# ### Q. Use the cheat sheet below to choose the algorithm/estimator suitable for building a model to address your candidate question(s)
#
# * https://scikit-learn.org/stable/tutorial/machine_learning_map/

# %% [markdown]
# ![Screenshot (4).png](data:image/png;base64,...)

# %% [markdown]
# # Part 4: Model Evaluation

# %% [markdown]
# ### Q. Identify which of the statistical measures below are suitable for the evaluation of your model.
#
# Classification Metrics:
# * Accuracy
# * Precision
# * Recall
# * F1 Score
#
# Regression Metrics:
#
# * Mean absolute error (MAE)
# * Root mean squared error (RMSE)
# * Relative absolute error (RAE)
# * Relative squared error (RSE)
# * Mean Zero One Error (MZOE)
# * Coefficient of determination

# %% [markdown]
# ![Screenshot (7).png](data:image/png;base64,...)

# %% [markdown]
# # Part 5: Stretch - Model Deployment

# %% [markdown]
# ### Q. Evaluate the open-source app framework for Machine Learning model deployment below in your own time.
#
# * https://streamlit.io/

# %%
import urllib.request
import json
import os
import ssl

def allowSelfSignedHttps(allowed):
    # bypass the server certificate verification on client side
    if allowed and not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None):
        ssl._create_default_https_context = ssl._create_unverified_context

allowSelfSignedHttps(True) # this line is needed if you use self-signed certificate in your scoring service.

# Request data goes here
data = {
    "Inputs": {
    },
    "GlobalParameters": {
    }
}

body = str.encode(json.dumps(data))

url = 'http://19400ca3-8051-4c4c-b929-7ed05fdb4c23.eastus.azurecontainer.io/score'
api_key = 'hp3NELQNPJeL9JLjkRYizwkJmNfsgNqo' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(error.read().decode("utf8", 'ignore'))
